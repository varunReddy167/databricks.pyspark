# %%
df=spark.read.csv("dbfs:/FileStore/moedes.csv",header=True)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>25</td></tr><tr><td>2</td><td>Alice</td><td>30</td></tr><tr><td>3</td><td>Bob</td><td>35</td></tr><tr><td>4</td><td>Sarah</td><td>twentyfive</td></tr><tr><td>5</td><td>Michael</td><td>40</td></tr></tbody></table></div>

# %%
df.createOrReplaceTempView('Test')

# %%
# %sql

select *from Test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>25</td></tr><tr><td>2</td><td>Alice</td><td>30</td></tr><tr><td>3</td><td>Bob</td><td>35</td></tr><tr><td>4</td><td>Sarah</td><td>twentyfive</td></tr><tr><td>5</td><td>Michael</td><td>40</td></tr></tbody></table></div>

# %%
df.createOrReplaceGlobalTempView('Global_test')

# %%
# %sql

select * from global_temp.global_test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>25</td></tr><tr><td>2</td><td>Alice</td><td>30</td></tr><tr><td>3</td><td>Bob</td><td>35</td></tr><tr><td>4</td><td>Sarah</td><td>twentyfive</td></tr><tr><td>5</td><td>Michael</td><td>40</td></tr></tbody></table></div>
