# %%
dbutils.fs.ls("dbfs:/Shared/Mypractice/")
# Out:
# Out[2]: [FileInfo(path='dbfs:/Shared/Mypractice/Nested.json/', name='Nested.json/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/Shared/Mypractice/emp.json', name='emp.json', size=2133, modificationTime=1688540374000),
#  FileInfo(path='dbfs:/Shared/Mypractice/multiline.json', name='multiline.json', size=1081, modificationTime=1688541166000)]

# %%
df=spark.read.option("header",True).option("mode","permissive").schema("id integer,name string,age int").csv("dbfs:/FileStore/moedes-1.csv" )
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>25</td></tr><tr><td>2</td><td>Alice</td><td>30</td></tr><tr><td>3</td><td>Bob</td><td>35</td></tr><tr><td>4</td><td>Sarah</td><td>null</td></tr><tr><td>5</td><td>Michael</td><td>40</td></tr></tbody></table></div>

# %%
df=spark.read.option("header",True).option("mode","dropmalformed").schema("id integer,name string,age int").csv("dbfs:/FileStore/moedes-1.csv" )
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>25</td></tr><tr><td>2</td><td>Alice</td><td>30</td></tr><tr><td>3</td><td>Bob</td><td>35</td></tr><tr><td>5</td><td>Michael</td><td>40</td></tr></tbody></table></div>

# %%
df=spark.read.option("header",True).option("badRecordsPath","dbfs:/temp/Badrecoreds").schema("id integer,name string,age int").csv("dbfs:/FileStore/moedes-1.csv" )
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>25</td></tr><tr><td>2</td><td>Alice</td><td>30</td></tr><tr><td>3</td><td>Bob</td><td>35</td></tr><tr><td>5</td><td>Michael</td><td>40</td></tr></tbody></table></div>

# %%
# %fs head dbfs:/temp/Badrecoreds/20230707T032451/bad_records/part-00000-e3e4854b-3761-44e2-b37f-e01d06844f9c
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;path&quot;:&quot;dbfs:/FileStore/moedes-1.csv&quot;,&quot;record&quot;:&quot;4,Sarah,twentyfive&quot;,&quot;reason&quot;:&quot;java.lang.NumberFormatException: For input string: \&quot;twentyfive\&quot;&quot;}
#
# </div>
